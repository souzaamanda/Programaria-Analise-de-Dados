# %% [markdown]
# # Exercicio Licitações

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/drive/MyDrive/Análise Dados - Programaria/licitacoes.csv', encoding='latin-1', sep=';')

# %% [markdown]
# ### Identifique qual coluna possui valores faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  int64
#  1   Código UG                 15336 non-null  int64
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  int64
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  int64
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  int64
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %% [markdown]
# ###  Identifique o tipo de dados desta coluna

# %%
dados.groupby('Data Abertura', dropna=False).nunique()
# Out:
#                Número Licitação  Código UG  Nome UG  Código Modalidade Compra  \
# Data Abertura
# 01/06/2018                    1          1        1                         1
# 01/10/2018                    5          5        5                         2
# 01/11/2018                   27         26       26                         3
# 01/12/2018                    1          1        1                         1
# 02/04/2018                    1          1        1                         1
# ...                         ...        ...      ...                       ...
# 31/07/2018                    1          1        1                         1
# 31/08/2018                    1          1        1                         1
# 31/10/2018                   27         31       31                         3
# 31/12/2018                    9          6        6                         2
# NaN                        1512       1708     1691                         8
#
# ...

# %%
dados['Data Abertura'].isnull().value_counts()
# Out:
# Data Abertura
# True     10648
# False     4688
# Name: count, dtype: int64

# %% [markdown]
# ### Substitua os valores faltantes pelo mesmo formato

# %%
datas_inexistentes = '01/01/1900'

# %%
dados[dados['Data Abertura'].isnull()] = datas_inexistentes

# %%
dados['Data Abertura'].isnull().value_counts()
# Out:
# Data Abertura
# False    15336
# Name: count, dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  object
#  1   Código UG                 15336 non-null  object
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  object
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  object
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  object
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %%
dados.groupby('Data Abertura', dropna=False).nunique()
# Out:
#                Número Licitação  Código UG  Nome UG  Código Modalidade Compra  \
# Data Abertura
# 01/01/1900                    1          1        1                         1
# 01/06/2018                    1          1        1                         1
# 01/10/2018                    5          5        5                         2
# 01/11/2018                   27         26       26                         3
# 01/12/2018                    1          1        1                         1
# ...                         ...        ...      ...                       ...
# 31/01/2018                    1          1        1                         1
# 31/07/2018                    1          1        1                         1
# 31/08/2018                    1          1        1                         1
# 31/10/2018                   27         31       31                         3
# 31/12/2018                    9          6        6                         2
#
# ...

# %% [markdown]
# # Exercicio Municipios Brasileiros

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
dados2 = pd.read_csv('/content/drive/MyDrive/Análise Dados - Programaria/municipios_brasileiros.csv')

# %%
dados2.head()
# Out:
#    codigo_ibge       nome_municipio  codigo_uf  uf        estado  capital  \
# 0      5200050      Abadia de Goiás         52  GO         Goiás        0
# 1      3100104  Abadia dos Dourados         31  MG  Minas Gerais        0
# 2      5200100            Abadiânia         52  GO         Goiás        0
# 3      3100203               Abaeté         31  MG  Minas Gerais        0
# 4      1500107           Abaetetuba         15  PA          Pará        0
#
#    latitude  longitude
# 0 -16.75730   -49.4412
# 1 -18.48310   -47.3916
# 2 -16.19700   -48.7057
# 3 -19.15510   -45.4444
# 4  -1.72183   -48.8788
